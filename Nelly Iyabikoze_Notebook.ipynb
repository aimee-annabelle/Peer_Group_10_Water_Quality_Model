# %% [markdown]
# # Excercise - Creating our own custom Model

# %% [markdown]
# This is a notebook that provides a quick overview of how to create your own custom model. You will be creating a simple model.
# You will be utilizing Keras and Tensorflow

# %% [markdown]
# ## Water Quality Dataset
#
# This dataset contains water quality measurements and assessments related to potability, which is the suitability of water for human consumption. The dataset's primary objective is to provide insights into water quality parameters and assist in determining whether the water is potable or not. Each row in the dataset represents a water sample with specific attributes, and the "Potability" column indicates whether the water is suitable for consumption.
#
# https://www.kaggle.com/datasets/uom190346a/water-quality-and-potability?select=water_potability.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pyplot
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping

# %%
#LOAD THE DATA
# 📥 Data Loading
data = pd.read_csv('data/water_potability.csv')
data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# Plot the Data Appropriately

# %% [markdown]
# Histograms for each feature

# %%
data.hist(bins=20, figsize=(12, 8))
plt.tight_layout()
plt.show()

# %% [markdown]
# Correlation Heatmap

# %%
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# %% [markdown]
# Countplot of Target Labels

# %%
sns.countplot(x='Potability', data=data)
plt.title('Distribution of Potability Classes')
plt.show()

# %%
print(data.isnull().sum())
data = data.fillna(data.mean())
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
print(data.isnull().sum())
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
# generate 2d classification dataset
X = data.drop('Potability', axis=1)
Y = data['Potability']

# %%
print("Input shape: ",X.shape)
# Out:
# Input shape:  (3276, 9)

# %%
#from sklearn import train_test_split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %% [markdown]
# # Each Memeber Defines their model Here

# %%
# 📦 Model Definition by Nelly
def model_nelly():
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=regularizers.l1(0.001)))
    model.add(Dropout(0.3))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    
    optimizer = RMSprop(learning_rate=0.0005)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# %%
model = model_nelly()
model.summary()
# Out:
# c:\Users\Djafari\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,753 (10.75 KB)
#  Trainable params: 2,753 (10.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Start the training Process

# %%
# Define Early Stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    X_train, Y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, Y_val),
    callbacks=[early_stopping],
    verbose=1)
# Out:
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5304 - loss: 1020.7271 - val_accuracy: 0.6314 - val_loss: 131.9451
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5515 - loss: 511.2414 - val_accuracy: 0.6314 - val_loss: 51.9846
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5333 - loss: 319.3690 - val_accuracy: 0.6151 - val_loss: 3.6523
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5022 - loss: 183.5248 - val_accuracy: 0.3686 - val_loss: 11.6001
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5224 - loss: 93.1944 - val_accuracy: 0.3686 - val_loss: 4.6564
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5247 - loss: 31.9346 - val_accuracy: 0.6314 - val_loss: 0.7416
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5706 - loss: 10.5653 - val_accuracy: 0.6314 - val_loss: 0.7377
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5741 - loss: 7.8654 - val_accuracy: 0.6314 - val_loss: 0.7331
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5911 - loss: 3.6951 - val_accuracy: 0.6314 - val_loss: 0.7286
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5947 - loss: 2.4023 - val_accuracy: 0.6314 - val_loss: 0.7251
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6087 - loss: 1.1835 - val_accuracy: 0.6314 - val_loss: 0.7211
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5995 - loss: 2.3318 - val_accuracy: 0.6314 - val_loss: 0.7172
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6123 - loss: 1.9605 - val_accuracy: 0.6314 - val_loss: 0.7140
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6208 - loss: 1.0940 - val_accuracy: 0.6314 - val_loss: 0.7105
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5986 - loss: 1.3343 - val_accuracy: 0.6314 - val_loss: 0.7075
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6110 - loss: 1.0389 - val_accuracy: 0.6314 - val_loss: 0.7043
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5936 - loss: 1.5834 - val_accuracy: 0.6314 - val_loss: 0.7017
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5983 - loss: 0.8232 - val_accuracy: 0.6314 - val_loss: 0.6989
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5964 - loss: 0.8732 - val_accuracy: 0.6314 - val_loss: 0.6967
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5839 - loss: 0.8822 - val_accuracy: 0.6314 - val_loss: 0.6949
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6215 - loss: 0.9819 - val_accuracy: 0.6314 - val_loss: 0.6929
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6141 - loss: 0.8227 - val_accuracy: 0.6314 - val_loss: 0.6911
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6192 - loss: 0.7949 - val_accuracy: 0.6314 - val_loss: 0.6890
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6079 - loss: 0.8808 - val_accuracy: 0.6314 - val_loss: 0.6873
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6053 - loss: 0.8518 - val_accuracy: 0.6314 - val_loss: 0.6857
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6100 - loss: 0.7930 - val_accuracy: 0.6314 - val_loss: 0.6843
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5917 - loss: 1.1505 - val_accuracy: 0.6314 - val_loss: 0.6830
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5977 - loss: 0.7303 - val_accuracy: 0.6314 - val_loss: 0.6808
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5989 - loss: 0.7765 - val_accuracy: 0.6314 - val_loss: 0.6796
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5878 - loss: 0.7322 - val_accuracy: 0.6314 - val_loss: 0.6784
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5994 - loss: 0.8177 - val_accuracy: 0.6314 - val_loss: 0.6776
# Epoch 32/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5997 - loss: 0.6950 - val_accuracy: 0.6314 - val_loss: 0.6768
# Epoch 33/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6133 - loss: 0.8793 - val_accuracy: 0.6314 - val_loss: 0.6762
# Epoch 34/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5814 - loss: 0.7160 - val_accuracy: 0.6314 - val_loss: 0.6750
# Epoch 35/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5993 - loss: 0.6894 - val_accuracy: 0.6314 - val_loss: 0.6740
# Epoch 36/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6076 - loss: 0.7266 - val_accuracy: 0.6314 - val_loss: 0.6737
# Epoch 37/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6142 - loss: 0.7506 - val_accuracy: 0.6314 - val_loss: 0.6733
# Epoch 38/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6064 - loss: 0.8074 - val_accuracy: 0.6314 - val_loss: 0.6726
# Epoch 39/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6069 - loss: 0.7409 - val_accuracy: 0.6314 - val_loss: 0.6718
# Epoch 40/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6161 - loss: 0.6853 - val_accuracy: 0.6314 - val_loss: 0.6709
# Epoch 41/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5967 - loss: 0.6935 - val_accuracy: 0.6314 - val_loss: 0.6702
# Epoch 42/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5961 - loss: 0.7501 - val_accuracy: 0.6314 - val_loss: 0.6699
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5939 - loss: 0.7594 - val_accuracy: 0.6314 - val_loss: 0.6697
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6060 - loss: 0.7648 - val_accuracy: 0.6314 - val_loss: 0.6692
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6040 - loss: 0.6794 - val_accuracy: 0.6314 - val_loss: 0.6681
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6256 - loss: 0.7951 - val_accuracy: 0.6314 - val_loss: 0.6676
# Epoch 47/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5997 - loss: 0.6845 - val_accuracy: 0.6314 - val_loss: 0.6671
# Epoch 48/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5921 - loss: 0.8449 - val_accuracy: 0.6314 - val_loss: 0.6669
# Epoch 49/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5969 - loss: 0.6816 - val_accuracy: 0.6314 - val_loss: 0.6660
# Epoch 50/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5942 - loss: 0.7455 - val_accuracy: 0.6314 - val_loss: 0.6658
# Epoch 51/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5842 - loss: 0.7359 - val_accuracy: 0.6314 - val_loss: 0.6655
# Epoch 52/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5935 - loss: 0.8865 - val_accuracy: 0.6314 - val_loss: 0.6653
# Epoch 53/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6059 - loss: 0.6751 - val_accuracy: 0.6314 - val_loss: 0.6648
# Epoch 54/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6163 - loss: 0.6829 - val_accuracy: 0.6314 - val_loss: 0.6646
# Epoch 55/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6045 - loss: 0.6756 - val_accuracy: 0.6314 - val_loss: 0.6645
# Epoch 56/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5982 - loss: 0.7087 - val_accuracy: 0.6314 - val_loss: 0.6643
# Epoch 57/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5999 - loss: 0.6874 - val_accuracy: 0.6314 - val_loss: 0.6645
# Epoch 58/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6028 - loss: 0.6874 - val_accuracy: 0.6314 - val_loss: 0.6641
# Epoch 59/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6021 - loss: 0.6777 - val_accuracy: 0.6314 - val_loss: 0.6640
# Epoch 60/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5957 - loss: 0.7910 - val_accuracy: 0.6314 - val_loss: 0.6639
# Epoch 61/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5941 - loss: 0.7196 - val_accuracy: 0.6314 - val_loss: 0.6639
# Epoch 62/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6046 - loss: 0.6878 - val_accuracy: 0.6314 - val_loss: 0.6639
# Epoch 63/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6109 - loss: 0.7436 - val_accuracy: 0.6314 - val_loss: 0.6641
# Epoch 64/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5844 - loss: 0.6826 - val_accuracy: 0.6314 - val_loss: 0.6637
# Epoch 65/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6010 - loss: 1.0078 - val_accuracy: 0.6314 - val_loss: 0.6637
# Epoch 66/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6016 - loss: 0.7187 - val_accuracy: 0.6314 - val_loss: 0.6638
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6042 - loss: 0.6833 - val_accuracy: 0.6314 - val_loss: 0.6636
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6055 - loss: 0.6937 - val_accuracy: 0.6314 - val_loss: 0.6636
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5930 - loss: 0.6799 - val_accuracy: 0.6314 - val_loss: 0.6632
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6004 - loss: 0.6789 - val_accuracy: 0.6314 - val_loss: 0.6629
# Epoch 71/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5943 - loss: 0.6967 - val_accuracy: 0.6314 - val_loss: 0.6630
# Epoch 72/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6083 - loss: 0.7065 - val_accuracy: 0.6314 - val_loss: 0.6627
# Epoch 73/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6054 - loss: 0.7995 - val_accuracy: 0.6314 - val_loss: 0.6629
# Epoch 74/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5994 - loss: 0.7496 - val_accuracy: 0.6314 - val_loss: 0.6628
# Epoch 75/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6088 - loss: 0.7387 - val_accuracy: 0.6314 - val_loss: 0.6627
# Epoch 76/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6027 - loss: 0.7008 - val_accuracy: 0.6314 - val_loss: 0.6626
# Epoch 77/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5974 - loss: 0.7281 - val_accuracy: 0.6314 - val_loss: 0.6627
# Epoch 78/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6084 - loss: 0.7848 - val_accuracy: 0.6314 - val_loss: 0.6626
# Epoch 79/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6141 - loss: 0.7201 - val_accuracy: 0.6314 - val_loss: 0.6627
# Epoch 80/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6066 - loss: 0.8294 - val_accuracy: 0.6314 - val_loss: 0.6625
# Epoch 81/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6182 - loss: 0.7012 - val_accuracy: 0.6314 - val_loss: 0.6627
# Epoch 82/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6069 - loss: 0.6756 - val_accuracy: 0.6314 - val_loss: 0.6625
# Epoch 83/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6174 - loss: 0.7191 - val_accuracy: 0.6314 - val_loss: 0.6625
# Epoch 84/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6107 - loss: 0.6950 - val_accuracy: 0.6314 - val_loss: 0.6626
# Epoch 85/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6052 - loss: 0.7233 - val_accuracy: 0.6314 - val_loss: 0.6624
# Epoch 86/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6017 - loss: 0.6764 - val_accuracy: 0.6314 - val_loss: 0.6624
# Epoch 87/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5938 - loss: 0.7663 - val_accuracy: 0.6314 - val_loss: 0.6625
# Epoch 88/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5918 - loss: 0.6808 - val_accuracy: 0.6314 - val_loss: 0.6624
# Epoch 89/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6053 - loss: 0.6723 - val_accuracy: 0.6314 - val_loss: 0.6623
# Epoch 90/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5854 - loss: 0.7085 - val_accuracy: 0.6314 - val_loss: 0.6625
# Epoch 91/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5946 - loss: 0.6780 - val_accuracy: 0.6314 - val_loss: 0.6622
# Epoch 92/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6002 - loss: 0.7338 - val_accuracy: 0.6314 - val_loss: 0.6624
# Epoch 93/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5889 - loss: 0.6794 - val_accuracy: 0.6314 - val_loss: 0.6621
# Epoch 94/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5967 - loss: 0.7065 - val_accuracy: 0.6314 - val_loss: 0.6623
# Epoch 95/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6040 - loss: 0.6821 - val_accuracy: 0.6314 - val_loss: 0.6621
# Epoch 96/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6035 - loss: 0.6758 - val_accuracy: 0.6314 - val_loss: 0.6620
# Epoch 97/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6013 - loss: 0.6819 - val_accuracy: 0.6314 - val_loss: 0.6622
# Epoch 98/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5965 - loss: 0.7188 - val_accuracy: 0.6314 - val_loss: 0.6622
# Epoch 99/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5775 - loss: 0.6893 - val_accuracy: 0.6314 - val_loss: 0.6620
# Epoch 100/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6164 - loss: 0.6730 - val_accuracy: 0.6314 - val_loss: 0.6622

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, Y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6211 - loss: 0.6669
# Test Loss: 0.6658
# Test Accuracy: 0.6240

# %%
# Confusion matrix (visualized)
# Precision, Recall, F1-score, and Accuracy printed per class

from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Get predictions
y_pred_proba = model.predict(X_test)
y_pred = (y_pred_proba > 0.5).astype(int)

# Generate confusion matrix
cm = confusion_matrix(Y_test, y_pred)

# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Purples', xticklabels=['Not Potable', 'Potable'], yticklabels=['Not Potable', 'Potable'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Print classification report
print("\nClassification Report:")
print(classification_report(Y_test, y_pred, target_names=['Not Potable','Potable']))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#  Not Potable       0.62      1.00      0.77       307
#      Potable       0.00      0.00      0.00       185
#
#     accuracy                           0.62       492
#    macro avg       0.31      0.50      0.38       492
# weighted avg       0.39      0.62      0.48       492
# c:\Users\Djafari\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Djafari\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Djafari\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
