# %% [markdown]
# <a href="https://colab.research.google.com/github/aimee-annabelle/Peer_Group_10_Water_Quality_Model/blob/Armand/Armand_Kayiranga_formative_II_with_graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/yourrepo/Armand_Kayiranga_Model/blob/main/Armand_Kayiranga_formative_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Excercise - Creating our own custom Model

# %% [markdown]
# This is a notebook that provides a quick overview of how to create your own custom model. You will be creating a simple model.
# You will be utilizing Keras and Tensorflow

# %% [markdown]
# ## Water Quality Dataset
#
# This dataset contains water quality measurements and assessments related to potability, which is the suitability of water for human consumption. The dataset's primary objective is to provide insights into water quality parameters and assist in determining whether the water is potable or not. Each row in the dataset represents a water sample with specific attributes, and the "Potability" column indicates whether the water is suitable for consumption.
#
# https://www.kaggle.com/datasets/uom190346a/water-quality-and-potability?select=water_potability.csv

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#LOAD THE DATA
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/aimee-annabelle/Peer_Group_10_Water_Quality_Model/main/water_potability.csv")
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB
# None
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
missing_percentage = df.isnull().mean() * 100
print(missing_percentage)
# Out:
# ph                 14.987790
# Hardness            0.000000
# Solids              0.000000
# Chloramines         0.000000
# Sulfate            23.840049
# Conductivity        0.000000
# Organic_carbon      0.000000
# Trihalomethanes     4.945055
# Turbidity           0.000000
# Potability          0.000000
# dtype: float64

# %%
df.fillna(df.median(), inplace=True)
df.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.074194   196.369496  22014.092526     7.122277   333.608364
# std       1.470040    32.879761   8768.570828     1.583085    36.143851
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.277673   176.850538  15666.690297     6.127421   317.094638
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       7.870050   216.667456  27332.762127     8.114887   350.385756
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.407478     3.966786     0.390110
# std       80.824064        3.308162        15.769958     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        56.647656     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        76.666609     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %% [markdown]
# Plot the Data Appropriately

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X = df.drop("Potability", axis=1)
y = df["Potability"]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Model Definition by Armand Kayiranga

# %% [markdown]
# ### Correlation Heatmap

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap of Water Quality Features")
plt.show()

# %% [markdown]
# ### Feature Distribution - Histograms

# %%
df.hist(figsize=(12, 10), bins=20, color='skyblue', edgecolor='black')
plt.suptitle('Distribution of Water Quality Features')
plt.tight_layout()
plt.show()

# %%
def model_armand_kayiranga():
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense
    from tensorflow.keras import regularizers
    from tensorflow.keras.optimizers import Adam

    model = Sequential([
        Dense(32, activation='relu', input_shape=(X.shape[1],),
              kernel_regularizer=regularizers.l1(0.001)),
        Dense(16, activation='relu',
              kernel_regularizer=regularizers.l1(0.001)),
        Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', patience=10)
model = model_armand_kayiranga()
history = model.fit(trainX, trainy,
                    validation_data=(testX, testy),
                    epochs=100,
                    batch_size=32,
                    verbose=1,
                    callbacks=[es])
# Out:
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4854 - loss: 0.8746 - val_accuracy: 0.6338 - val_loss: 0.8046
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6058 - loss: 0.8051 - val_accuracy: 0.6409 - val_loss: 0.7814
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6380 - loss: 0.7765 - val_accuracy: 0.6531 - val_loss: 0.7647
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6517 - loss: 0.7621 - val_accuracy: 0.6673 - val_loss: 0.7427
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6665 - loss: 0.7385 - val_accuracy: 0.6734 - val_loss: 0.7278
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6816 - loss: 0.7247 - val_accuracy: 0.6745 - val_loss: 0.7169
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6762 - loss: 0.7107 - val_accuracy: 0.6826 - val_loss: 0.7057
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6729 - loss: 0.7053 - val_accuracy: 0.6867 - val_loss: 0.6989
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6728 - loss: 0.7093 - val_accuracy: 0.6877 - val_loss: 0.6926
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6883 - loss: 0.6960 - val_accuracy: 0.6836 - val_loss: 0.6869
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6946 - loss: 0.6824 - val_accuracy: 0.6877 - val_loss: 0.6828
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6879 - loss: 0.6830 - val_accuracy: 0.6897 - val_loss: 0.6795
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6794 - loss: 0.6880 - val_accuracy: 0.6846 - val_loss: 0.6777
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7008 - loss: 0.6647 - val_accuracy: 0.6907 - val_loss: 0.6745
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6932 - loss: 0.6696 - val_accuracy: 0.6958 - val_loss: 0.6730
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7053 - loss: 0.6634 - val_accuracy: 0.6968 - val_loss: 0.6711
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6860 - loss: 0.6712 - val_accuracy: 0.6907 - val_loss: 0.6699
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7203 - loss: 0.6432 - val_accuracy: 0.6928 - val_loss: 0.6677
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6846 - loss: 0.6603 - val_accuracy: 0.6887 - val_loss: 0.6662
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6896 - loss: 0.6689 - val_accuracy: 0.6857 - val_loss: 0.6658
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7020 - loss: 0.6562 - val_accuracy: 0.6867 - val_loss: 0.6640
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6997 - loss: 0.6543 - val_accuracy: 0.6887 - val_loss: 0.6629
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7027 - loss: 0.6475 - val_accuracy: 0.6826 - val_loss: 0.6609
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7049 - loss: 0.6409 - val_accuracy: 0.6826 - val_loss: 0.6604
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6862 - loss: 0.6634 - val_accuracy: 0.6857 - val_loss: 0.6589
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6851 - loss: 0.6578 - val_accuracy: 0.6887 - val_loss: 0.6583
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7068 - loss: 0.6472 - val_accuracy: 0.6887 - val_loss: 0.6578
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6994 - loss: 0.6417 - val_accuracy: 0.6897 - val_loss: 0.6586
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6967 - loss: 0.6471 - val_accuracy: 0.6857 - val_loss: 0.6570
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6851 - loss: 0.6511 - val_accuracy: 0.6796 - val_loss: 0.6571
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6848 - loss: 0.6555 - val_accuracy: 0.6897 - val_loss: 0.6550
# Epoch 32/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7044 - loss: 0.6418 - val_accuracy: 0.6857 - val_loss: 0.6548
# Epoch 33/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6973 - loss: 0.6338 - val_accuracy: 0.6826 - val_loss: 0.6557
# Epoch 34/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6933 - loss: 0.6452 - val_accuracy: 0.6887 - val_loss: 0.6542
# Epoch 35/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7182 - loss: 0.6216 - val_accuracy: 0.6877 - val_loss: 0.6537
# Epoch 36/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7101 - loss: 0.6351 - val_accuracy: 0.6887 - val_loss: 0.6527
# Epoch 37/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7067 - loss: 0.6369 - val_accuracy: 0.6785 - val_loss: 0.6542
# Epoch 38/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7025 - loss: 0.6371 - val_accuracy: 0.6887 - val_loss: 0.6516
# Epoch 39/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6963 - loss: 0.6320 - val_accuracy: 0.6826 - val_loss: 0.6507
# Epoch 40/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6981 - loss: 0.6321 - val_accuracy: 0.6867 - val_loss: 0.6511
# Epoch 41/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7098 - loss: 0.6214 - val_accuracy: 0.6897 - val_loss: 0.6513
# Epoch 42/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6995 - loss: 0.6304 - val_accuracy: 0.6887 - val_loss: 0.6501
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7071 - loss: 0.6226 - val_accuracy: 0.6816 - val_loss: 0.6500
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7138 - loss: 0.6184 - val_accuracy: 0.6775 - val_loss: 0.6514
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7078 - loss: 0.6198 - val_accuracy: 0.6877 - val_loss: 0.6492
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7114 - loss: 0.6164 - val_accuracy: 0.6836 - val_loss: 0.6487
# Epoch 47/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7082 - loss: 0.6297 - val_accuracy: 0.6846 - val_loss: 0.6476
# Epoch 48/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7157 - loss: 0.6233 - val_accuracy: 0.6877 - val_loss: 0.6492
# Epoch 49/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7052 - loss: 0.6243 - val_accuracy: 0.6948 - val_loss: 0.6471
# Epoch 50/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6907 - loss: 0.6302 - val_accuracy: 0.6836 - val_loss: 0.6476
# Epoch 51/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6976 - loss: 0.6393 - val_accuracy: 0.6918 - val_loss: 0.6477
# Epoch 52/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7016 - loss: 0.6336 - val_accuracy: 0.6897 - val_loss: 0.6462
# Epoch 53/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7148 - loss: 0.6245 - val_accuracy: 0.6907 - val_loss: 0.6462
# Epoch 54/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7087 - loss: 0.6244 - val_accuracy: 0.6958 - val_loss: 0.6470
# Epoch 55/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7174 - loss: 0.6149 - val_accuracy: 0.6826 - val_loss: 0.6467
# Epoch 56/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7147 - loss: 0.6162 - val_accuracy: 0.6877 - val_loss: 0.6479
# Epoch 57/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7063 - loss: 0.6278 - val_accuracy: 0.6846 - val_loss: 0.6456
# Epoch 58/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6908 - loss: 0.6266 - val_accuracy: 0.6867 - val_loss: 0.6465
# Epoch 59/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7085 - loss: 0.6232 - val_accuracy: 0.6867 - val_loss: 0.6467
# Epoch 60/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7155 - loss: 0.6142 - val_accuracy: 0.6846 - val_loss: 0.6479
# Epoch 61/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7102 - loss: 0.6222 - val_accuracy: 0.6907 - val_loss: 0.6461
# Epoch 62/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7067 - loss: 0.6229 - val_accuracy: 0.6897 - val_loss: 0.6464
# Epoch 63/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7217 - loss: 0.6146 - val_accuracy: 0.6816 - val_loss: 0.6459
# Epoch 64/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7089 - loss: 0.6113 - val_accuracy: 0.6775 - val_loss: 0.6456
# Epoch 65/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7129 - loss: 0.6260 - val_accuracy: 0.6877 - val_loss: 0.6458
# Epoch 66/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7148 - loss: 0.6094 - val_accuracy: 0.6755 - val_loss: 0.6521
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7036 - loss: 0.6238 - val_accuracy: 0.6796 - val_loss: 0.6446
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7048 - loss: 0.6286 - val_accuracy: 0.6846 - val_loss: 0.6450
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7166 - loss: 0.6100 - val_accuracy: 0.6877 - val_loss: 0.6454
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7264 - loss: 0.6124 - val_accuracy: 0.6826 - val_loss: 0.6448
# Epoch 71/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7102 - loss: 0.6084 - val_accuracy: 0.6796 - val_loss: 0.6469
# Epoch 72/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7315 - loss: 0.5946 - val_accuracy: 0.6704 - val_loss: 0.6474
# Epoch 73/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7364 - loss: 0.6036 - val_accuracy: 0.6816 - val_loss: 0.6450
# Epoch 74/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7125 - loss: 0.6194 - val_accuracy: 0.6816 - val_loss: 0.6454
# Epoch 75/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7018 - loss: 0.6138 - val_accuracy: 0.6877 - val_loss: 0.6451
# Epoch 76/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7125 - loss: 0.6026 - val_accuracy: 0.6734 - val_loss: 0.6485
# Epoch 77/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7140 - loss: 0.6189 - val_accuracy: 0.6846 - val_loss: 0.6445
# Epoch 78/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7291 - loss: 0.6058 - val_accuracy: 0.6826 - val_loss: 0.6456
# Epoch 79/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7105 - loss: 0.6109 - val_accuracy: 0.6806 - val_loss: 0.6457
# Epoch 80/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7174 - loss: 0.6140 - val_accuracy: 0.6836 - val_loss: 0.6458
# Epoch 81/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7118 - loss: 0.6065 - val_accuracy: 0.6826 - val_loss: 0.6460
# Epoch 82/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7228 - loss: 0.6042 - val_accuracy: 0.6918 - val_loss: 0.6455
# Epoch 83/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7040 - loss: 0.6157 - val_accuracy: 0.6836 - val_loss: 0.6451
# Epoch 84/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7032 - loss: 0.6209 - val_accuracy: 0.6724 - val_loss: 0.6477
# Epoch 85/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7102 - loss: 0.6127 - val_accuracy: 0.6704 - val_loss: 0.6471
# Epoch 86/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7113 - loss: 0.6018 - val_accuracy: 0.6857 - val_loss: 0.6479
# Epoch 87/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7080 - loss: 0.6044 - val_accuracy: 0.6734 - val_loss: 0.6468

# %%
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('Train Accuracy: %.3f, Test Accuracy: %.3f' % (train_acc, test_acc))
# Out:
# Train Accuracy: 0.717, Test Accuracy: 0.673

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.title("Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.show()
